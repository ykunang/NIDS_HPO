# %%
import pandas as pd

# %%
# read back in from disk
df = pd.read_csv('./hasil/talos.csv')

# %%
df['nodes'] = df.first_neuron + df.second_neuron+df.third_neuron+df.fourth_neuron
df['links'] =  df.nodes * (df.nodes-1) / 2
base_acc=0.9774341310990117
df['val_DetectRate_improvement'] = df.acc - base_acc
#compare to baseline log-loss (higher is better)
print(df.sort_values('acc').head())
# Out:
#      round_epochs    val_loss   val_acc      loss       acc  hidden_layer  \
# 256            30   43.106077  0.556220  1.483922  0.433100             2
# 255            30  135.435620  0.556221  1.444560  0.441507             2
# 254            30    6.670646  0.556220  1.472923  0.441557             2
# 397            30    5.095023  0.556221  1.382412  0.475434             2
# 396            30    7.068883  0.561432  8.389111  0.479522             2
#
#      first_neuron  second_neuron  third_neuron  fourth_neuron  ...  epochs  \
# 256            60             15             0              0  ...      20
# 255            70             15             0              0  ...      20
# 254            70             30             0              0  ...      20
# 397            50             15             0              0  ...      20
# 396            70             30             0              0  ...      20
#
#      epochs2  dropout  kernel_initializer                        optimizer  \
# 256       30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 255       30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 254       30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 397       30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 396       30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
#
#       lr  activation nodes   links  val_DetectRate_improvement
# 256  0.1        SELU    75  2775.0                   -0.544334
# 255  0.1        SELU    85  3570.0                   -0.535928
# 254  0.1        SELU   100  4950.0                   -0.535877
# 397  0.1       PReLU    65  2080.0                   -0.502000
# 396  0.1        SELU   100  4950.0                   -0.497912
#
# [5 rows x 21 columns]

# %%
df.sort_values('acc', ascending=False)
# Out:
#       round_epochs    val_loss   val_acc      loss       acc  hidden_layer  \
# 717             30    2.409385  0.848090  0.041286  0.978182             3
# 639             30    2.446396  0.848078  0.041865  0.978088             3
# 303             30    2.445924  0.848093  0.041616  0.978068             2
# 640             30    2.445330  0.848041  0.041495  0.978068             3
# 641             30    2.445591  0.848130  0.041703  0.978052             3
# 842             30    2.445329  0.848038  0.041447  0.978042             4
# 1006            30    2.446497  0.848044  0.041498  0.978011             4
# 642             30    2.445359  0.848164  0.042632  0.977988             3
# 1007            30    2.446104  0.848075  0.042270  0.977986             4
# 843             30    2.447577  0.847914  0.041970  0.977955             4
# 643             30    2.446441  0.848102  0.042778  0.977940             3
# 503             30    2.446512  0.848059  0.041724  0.977935             3
# 844             30    2.447998  0.847920  0.042639  0.977934             4
# 1008            30    2.445789  0.848053  0.042426  0.977922             4
# 644             30    2.448194  0.847896  0.042687  0.977910             3
# 845             30    2.446845  0.847942  0.041729  0.977899             4
# 954             30    2.350477  0.848050  0.041787  0.977892             4
# 718             30    2.446955  0.847930  0.043083  0.977891             3
# 645             30    2.449193  0.847862  0.041954  0.977891             3
# 646             30    2.445903  0.848068  0.041762  0.977889             3
# 846             30    2.446752  0.847923  0.041786  0.977887             4
# 904             30    2.417604  0.847997  0.041927  0.977882             4
# 719             30    2.445713  0.848072  0.041953  0.977880             3
# 1009            30    2.447598  0.847951  0.042805  0.977876             4
# 504             30    2.443839  0.848158  0.041758  0.977874             3
# 955             30    2.446450  0.848013  0.042559  0.977870             4
# 647             30    2.441704  0.848044  0.041851  0.977866             3
# 257             30    2.446003  0.848056  0.041999  0.977839             2
# 1010            30    2.446699  0.848001  0.042530  0.977838             4
# 956             30    2.445561  0.848084  0.041813  0.977825             4
# ...            ...         ...       ...       ...       ...           ...
# 710             30    7.068883  0.561432  7.869731  0.504597             3
# 711             30    7.069530  0.561392  7.896020  0.503543             3
# 501             30    7.068883  0.561432  7.960578  0.502560             3
# 302             30    7.068883  0.561432  5.841507  0.500198             2
# 712             30    7.068883  0.561432  7.972089  0.499866             3
# 713             30    7.068883  0.561432  7.925341  0.499529             3
# 783             30    7.068883  0.561432  7.841114  0.497419             3
# 714             30    7.068883  0.561432  8.043589  0.497070             3
# 715             30    7.068883  0.561432  8.063278  0.495064             3
# 250             30    7.068883  0.561432  8.116141  0.494772             2
# 784             30    7.068883  0.561432  7.455965  0.494114             3
# 251             30    2.902577  0.561432  4.476075  0.493419             2
# 716             30    7.080330  0.560722  8.026823  0.493244             3
# 785             30    7.068883  0.561432  7.646503  0.491782             3
# 786             30    7.068883  0.561432  7.035003  0.491425             3
# 787             30    3.374322  0.561432  1.604058  0.488697             3
# 252             30    7.068883  0.561432  8.216864  0.488472             2
# 788             30    3.443659  0.561432  1.607119  0.488153             3
# 789             30    3.476756  0.561432  1.593058  0.485945             3
# 395             30    7.068883  0.561432  7.232500  0.485863             2
# 790             30    7.068883  0.561432  7.679654  0.485375             3
# 791             30    3.541899  0.561432  1.691087  0.483296             3
# 253             30    7.068883  0.561432  8.336419  0.482197             2
# 792             30    7.068883  0.561432  7.734777  0.481377             3
# 502             30    7.068883  0.561432  8.384348  0.479690             3
# 396             30    7.068883  0.561432  8.389111  0.479522             2
# 397             30    5.095023  0.556221  1.382412  0.475434             2
# 254             30    6.670646  0.556220  1.472923  0.441557             2
# 255             30  135.435620  0.556221  1.444560  0.441507             2
# 256             30   43.106077  0.556220  1.483922  0.433100             2
#
#       first_neuron  second_neuron  third_neuron  fourth_neuron  ...  epochs  \
# 717             60             30            25              0  ...      20
# 639             70             30            25              0  ...      20
# 303             60             35             0              0  ...      20
# 640             50             40            25              0  ...      20
# 641             60             40            25              0  ...      20
# 842             70             40            30             25  ...      20
# 1006            60             50            30             25  ...      20
# 642             70             30            20              0  ...      20
# 1007            60             50            30             20  ...      20
# 843             60             40            35             20  ...      20
# 643             50             30            25              0  ...      20
# 503             50             30            25              0  ...      20
# 844             60             50            35             25  ...      20
# 1008            60             40            30             25  ...      20
# 644             60             40            20              0  ...      20
# 845             60             40            30             20  ...      20
# 954             60             40            35             25  ...      20
# 718             70             40            20              0  ...      20
# 645             70             30            20              0  ...      20
# 646             60             30            20              0  ...      20
# 846             70             40            30             25  ...      20
# 904             70             40            35             25  ...      20
# 719             60             30            20              0  ...      20
# 1009            60             40            35             20  ...      20
# 504             70             40            25              0  ...      20
# 955             70             50            30             20  ...      20
# 647             60             30            25              0  ...      20
# 257             50             20             0              0  ...      20
# 1010            60             50            30             20  ...      20
# 956             70             50            30             25  ...      20
# ...            ...            ...           ...            ...  ...     ...
# 710             50             40            20              0  ...      20
# 711             60             40            20              0  ...      20
# 501             60             35            25              0  ...      20
# 302             60             30             0              0  ...      20
# 712             70             35            25              0  ...      20
# 713             60             40            20              0  ...      20
# 783             60             35            20              0  ...      20
# 714             50             30            25              0  ...      20
# 715             70             35            25              0  ...      20
# 250             70             25             0              0  ...      20
# 784             50             30            20              0  ...      20
# 251             50             20             0              0  ...      20
# 716             50             35            20              0  ...      20
# 785             50             40            20              0  ...      20
# 786             50             40            25              0  ...      20
# 787             70             35            25              0  ...      20
# 252             70             25             0              0  ...      20
# 788             60             35            20              0  ...      20
# 789             70             35            25              0  ...      20
# 395             70             35             0              0  ...      20
# 790             60             30            20              0  ...      20
# 791             70             35            20              0  ...      20
# 253             50             25             0              0  ...      20
# 792             60             40            20              0  ...      20
# 502             70             40            25              0  ...      20
# 396             70             30             0              0  ...      20
# 397             50             15             0              0  ...      20
# 254             70             30             0              0  ...      20
# 255             70             15             0              0  ...      20
# 256             60             15             0              0  ...      20
#
#       epochs2  dropout  kernel_initializer                        optimizer  \
# 717        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 639        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 303        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 640        30        0          he_uniform  <class 'keras.optimizers.Adam'>
# 641        30        0       glorot_normal  <class 'keras.optimizers.Adam'>
# 842        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 1006       30        0           he_normal  <class 'keras.optimizers.Adam'>
# 642        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 1007       30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 843        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 643        30        0              normal  <class 'keras.optimizers.Adam'>
# 503        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 844        30        0       glorot_normal  <class 'keras.optimizers.Adam'>
# 1008       30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 644        30        0              normal  <class 'keras.optimizers.Adam'>
# 845        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 954        30        0       glorot_normal  <class 'keras.optimizers.Adam'>
# 718        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 645        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 646        30        0       glorot_normal  <class 'keras.optimizers.Adam'>
# 846        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 904        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 719        30        0          he_uniform  <class 'keras.optimizers.Adam'>
# 1009       30        0          he_uniform  <class 'keras.optimizers.Adam'>
# 504        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 955        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 647        30        0              normal  <class 'keras.optimizers.Adam'>
# 257        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 1010       30        0          he_uniform  <class 'keras.optimizers.Adam'>
# 956        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# ...       ...      ...                 ...                              ...
# 710        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 711        30        0              normal  <class 'keras.optimizers.Adam'>
# 501        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 302        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 712        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 713        30        0          he_uniform  <class 'keras.optimizers.Adam'>
# 783        30        0       glorot_normal  <class 'keras.optimizers.Adam'>
# 714        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 715        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 250        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 784        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 251        30        0          he_uniform  <class 'keras.optimizers.Adam'>
# 716        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 785        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 786        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 787        30        0       glorot_normal  <class 'keras.optimizers.Adam'>
# 252        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 788        30        0          he_uniform  <class 'keras.optimizers.Adam'>
# 789        30        0          he_uniform  <class 'keras.optimizers.Adam'>
# 395        30        0       glorot_normal  <class 'keras.optimizers.Adam'>
# 790        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 791        30        0              normal  <class 'keras.optimizers.Adam'>
# 253        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 792        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 502        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 396        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 397        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 254        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 255        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 256        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
#
#           lr  activation nodes    links  val_DetectRate_improvement
# 717   0.0010        ReLU   115   6555.0                    0.000748
# 639   0.0010   LeakyReLU   125   7750.0                    0.000654
# 303   0.0010   LeakyReLU    95   4465.0                    0.000634
# 640   0.0010   LeakyReLU   115   6555.0                    0.000634
# 641   0.0010   LeakyReLU   125   7750.0                    0.000618
# 842   0.0010   LeakyReLU   165  13530.0                    0.000608
# 1006  0.0001        ReLU   165  13530.0                    0.000577
# 642   0.0010   LeakyReLU   120   7140.0                    0.000553
# 1007  0.0010        ReLU   160  12720.0                    0.000552
# 843   0.0010   LeakyReLU   155  11935.0                    0.000521
# 643   0.0010   LeakyReLU   105   5460.0                    0.000506
# 503   0.0010         ELU   105   5460.0                    0.000501
# 844   0.0010   LeakyReLU   170  14365.0                    0.000499
# 1008  0.0010        ReLU   155  11935.0                    0.000488
# 644   0.0010   LeakyReLU   120   7140.0                    0.000476
# 845   0.0010   LeakyReLU   150  11175.0                    0.000465
# 954   0.0010         ELU   160  12720.0                    0.000458
# 718   0.0010        ReLU   130   8385.0                    0.000457
# 645   0.0001   LeakyReLU   120   7140.0                    0.000457
# 646   0.0010   LeakyReLU   110   5995.0                    0.000455
# 846   0.0010   LeakyReLU   165  13530.0                    0.000453
# 904   0.0010        SELU   170  14365.0                    0.000448
# 719   0.0010        ReLU   110   5995.0                    0.000445
# 1009  0.0010        ReLU   155  11935.0                    0.000442
# 504   0.0010         ELU   135   9045.0                    0.000440
# 955   0.0010         ELU   170  14365.0                    0.000436
# 647   0.0010   LeakyReLU   115   6555.0                    0.000432
# 257   0.0010        ReLU    70   2415.0                    0.000405
# 1010  0.0010        ReLU   160  12720.0                    0.000404
# 956   0.0010         ELU   175  15225.0                    0.000391
# ...      ...         ...   ...      ...                         ...
# 710   0.1000   LeakyReLU   110   5995.0                   -0.472837
# 711   0.1000   LeakyReLU   120   7140.0                   -0.473891
# 501   0.1000       PReLU   120   7140.0                   -0.474874
# 302   0.1000        ReLU    90   4005.0                   -0.477237
# 712   0.1000   LeakyReLU   130   8385.0                   -0.477568
# 713   0.1000   LeakyReLU   120   7140.0                   -0.477905
# 783   0.1000        ReLU   115   6555.0                   -0.480015
# 714   0.1000   LeakyReLU   105   5460.0                   -0.480364
# 715   0.1000   LeakyReLU   130   8385.0                   -0.482370
# 250   0.1000        SELU    95   4465.0                   -0.482662
# 784   0.1000        ReLU   100   4950.0                   -0.483320
# 251   0.1000        SELU    70   2415.0                   -0.484016
# 716   0.1000   LeakyReLU   105   5460.0                   -0.484190
# 785   0.1000        ReLU   110   5995.0                   -0.485652
# 786   0.1000        ReLU   115   6555.0                   -0.486010
# 787   0.1000        ReLU   130   8385.0                   -0.488738
# 252   0.1000        SELU    95   4465.0                   -0.488962
# 788   0.1000        ReLU   115   6555.0                   -0.489281
# 789   0.1000        ReLU   130   8385.0                   -0.491489
# 395   0.1000         ELU   105   5460.0                   -0.491571
# 790   0.1000        ReLU   110   5995.0                   -0.492059
# 791   0.1000        ReLU   125   7750.0                   -0.494138
# 253   0.1000        SELU    75   2775.0                   -0.495237
# 792   0.1000        ReLU   120   7140.0                   -0.496057
# 502   0.1000       PReLU   135   9045.0                   -0.497744
# 396   0.1000        SELU   100   4950.0                   -0.497912
# 397   0.1000       PReLU    65   2080.0                   -0.502000
# 254   0.1000        SELU   100   4950.0                   -0.535877
# 255   0.1000        SELU    85   3570.0                   -0.535928
# 256   0.1000        SELU    75   2775.0                   -0.544334
#
# [1062 rows x 21 columns]

# %%
df.sort_values('val_acc', ascending=False)
# Out:
#       round_epochs    val_loss   val_acc      loss       acc  hidden_layer  \
# 267             30    6.613824  0.850966  0.042880  0.977036             2
# 414             30    7.611172  0.850963  0.044900  0.976301             2
# 205             30    3.746093  0.850948  0.042596  0.977808             2
# 406             30    7.083116  0.850948  0.044594  0.976540             2
# 316             30    6.655684  0.850937  0.044013  0.977293             2
# 227             30    4.945937  0.850936  0.047360  0.975160             2
# 209             30    6.353614  0.850925  0.043043  0.977194             2
# 351             30    7.280146  0.850896  0.043800  0.976754             2
# 425             30    8.138351  0.850885  0.046623  0.975710             2
# 264             30    9.170313  0.850885  0.043840  0.977288             2
# 213             30    5.004397  0.850885  0.043475  0.976885             2
# 448             30    9.493912  0.850884  0.050338  0.973037             2
# 437             30    7.607094  0.850873  0.046723  0.975304             2
# 449             30   14.540612  0.850859  0.051778  0.972243             2
# 313             30    9.580496  0.850859  0.043141  0.977495             2
# 263             30    6.694669  0.850850  0.043484  0.977554             2
# 359             30    6.923756  0.850849  0.044469  0.976562             2
# 221             30    6.688469  0.850839  0.047305  0.976013             2
# 446             30    7.579109  0.850833  0.050243  0.973466             2
# 384             30   22.705910  0.850754  0.055878  0.972497             2
# 444             30    5.083558  0.850741  0.049171  0.974486             2
# 284             30   11.429934  0.850729  0.048013  0.974497             2
# 270             30    5.621764  0.850689  0.044495  0.976931             2
# 331             30    5.152040  0.850674  0.048144  0.974909             2
# 329             30    5.897989  0.850631  0.047012  0.975148             2
# 328             30    4.867746  0.850604  0.048068  0.975637             2
# 440             30    5.192721  0.850556  0.049278  0.974752             2
# 438             30    4.496396  0.850512  0.048501  0.974883             2
# 380             30    4.709371  0.850477  0.048958  0.974745             2
# 336             30   31.133844  0.850412  0.055449  0.972686             2
# ...            ...         ...       ...       ...       ...           ...
# 243             30    7.068886  0.561432  6.922644  0.565008             2
# 701             30    7.068933  0.561429  6.416450  0.582921             3
# 342             30    7.068933  0.561429  7.026427  0.555819             2
# 778             30    7.068933  0.561426  6.708685  0.553825             3
# 340             30    7.069182  0.561413  6.834208  0.567250             2
# 777             30    7.068927  0.561398  4.263839  0.573008             3
# 711             30    7.069530  0.561392  7.896020  0.503543             3
# 1000            30    3.078099  0.561281  1.047910  0.805235             4
# 247             30    7.073761  0.561129  7.422085  0.532718             2
# 160             30    7.075801  0.561003  5.507707  0.648985             1
# 245             30    7.075803  0.561003  7.376343  0.538571             2
# 110             30    7.077593  0.560891  4.100410  0.743849             1
# 999             30    7.078290  0.560848  1.891412  0.806335             4
# 779             30    3.285587  0.560774  1.370374  0.542182             3
# 249             30    7.079882  0.560749  7.909544  0.508859             2
# 716             30    7.080330  0.560722  8.026823  0.493244             3
# 774             30    4.067603  0.560123  2.101956  0.627934             3
# 707             30    7.119747  0.558276  7.726941  0.509729             3
# 111             30    7.135377  0.557304  5.420657  0.661925             1
# 397             30    5.095023  0.556221  1.382412  0.475434             2
# 294             30    4.601826  0.556221  0.448004  0.807845             2
# 255             30  135.435620  0.556221  1.444560  0.441507             2
# 256             30   43.106077  0.556220  1.483922  0.433100             2
# 254             30    6.670646  0.556220  1.472923  0.441557             2
# 300             30    4.909540  0.556200  1.239974  0.525099             2
# 902             30    7.257656  0.549720  2.819534  0.797180             4
# 703             30    7.402680  0.540722  7.492346  0.525172             3
# 1061            30    3.296671  0.540330  1.209614  0.839400             4
# 338             30    7.562172  0.530817  2.892295  0.796019             2
# 769             30    3.106167  0.510753  1.108666  0.744022             3
#
#       first_neuron  second_neuron  third_neuron  fourth_neuron  ...  epochs  \
# 267             60             25             0              0  ...      20
# 414             50             20             0              0  ...      20
# 205             60             25             0              0  ...      20
# 406             70             20             0              0  ...      20
# 316             70             25             0              0  ...      20
# 227             60             25             0              0  ...      20
# 209             50             35             0              0  ...      20
# 351             60             15             0              0  ...      20
# 425             50             15             0              0  ...      20
# 264             70             20             0              0  ...      20
# 213             60             15             0              0  ...      20
# 448             50             30             0              0  ...      20
# 437             60             20             0              0  ...      20
# 449             70             25             0              0  ...      20
# 313             50             35             0              0  ...      20
# 263             50             35             0              0  ...      20
# 359             60             15             0              0  ...      20
# 221             60             25             0              0  ...      20
# 446             50             25             0              0  ...      20
# 384             50             30             0              0  ...      20
# 444             50             25             0              0  ...      20
# 284             70             35             0              0  ...      20
# 270             50             35             0              0  ...      20
# 331             60             35             0              0  ...      20
# 329             60             25             0              0  ...      20
# 328             50             25             0              0  ...      20
# 440             70             35             0              0  ...      20
# 438             70             20             0              0  ...      20
# 380             70             30             0              0  ...      20
# 336             50             15             0              0  ...      20
# ...            ...            ...           ...            ...  ...     ...
# 243             60             25             0              0  ...      20
# 701             60             35            20              0  ...      20
# 342             70             30             0              0  ...      20
# 778             70             40            25              0  ...      20
# 340             60             30             0              0  ...      20
# 777             70             40            25              0  ...      20
# 711             60             40            20              0  ...      20
# 1000            60             50            30             25  ...      20
# 247             50             30             0              0  ...      20
# 160             30              0             0              0  ...      20
# 245             50             35             0              0  ...      20
# 110             50              0             0              0  ...      20
# 999             70             40            30             20  ...      20
# 779             50             30            20              0  ...      20
# 249             50             35             0              0  ...      20
# 716             50             35            20              0  ...      20
# 774             70             40            25              0  ...      20
# 707             60             30            25              0  ...      20
# 111             50              0             0              0  ...      20
# 397             50             15             0              0  ...      20
# 294             70             15             0              0  ...      20
# 255             70             15             0              0  ...      20
# 256             60             15             0              0  ...      20
# 254             70             30             0              0  ...      20
# 300             70             30             0              0  ...      20
# 902             70             40            30             25  ...      20
# 703             70             30            20              0  ...      20
# 1061            70             50            30             20  ...      20
# 338             60             30             0              0  ...      20
# 769             70             30            25              0  ...      20
#
#       epochs2  dropout  kernel_initializer                        optimizer  \
# 267        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 414        30        0       glorot_normal  <class 'keras.optimizers.Adam'>
# 205        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 406        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 316        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 227        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 209        30        0          he_uniform  <class 'keras.optimizers.Adam'>
# 351        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 425        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 264        30        0          he_uniform  <class 'keras.optimizers.Adam'>
# 213        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 448        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 437        30        0          he_uniform  <class 'keras.optimizers.Adam'>
# 449        30        0       glorot_normal  <class 'keras.optimizers.Adam'>
# 313        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 263        30        0       glorot_normal  <class 'keras.optimizers.Adam'>
# 359        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 221        30        0              normal  <class 'keras.optimizers.Adam'>
# 446        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 384        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 444        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 284        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 270        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 331        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 329        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 328        30        0          he_uniform  <class 'keras.optimizers.Adam'>
# 440        30        0              normal  <class 'keras.optimizers.Adam'>
# 438        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 380        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 336        30        0          he_uniform  <class 'keras.optimizers.Adam'>
# ...       ...      ...                 ...                              ...
# 243        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 701        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 342        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 778        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 340        30        0          he_uniform  <class 'keras.optimizers.Adam'>
# 777        30        0       glorot_normal  <class 'keras.optimizers.Adam'>
# 711        30        0              normal  <class 'keras.optimizers.Adam'>
# 1000       30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 247        30        0       glorot_normal  <class 'keras.optimizers.Adam'>
# 160        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 245        30        0          he_uniform  <class 'keras.optimizers.Adam'>
# 110        30        0          he_uniform  <class 'keras.optimizers.Adam'>
# 999        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 779        30        0              normal  <class 'keras.optimizers.Adam'>
# 249        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 716        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 774        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 707        30        0       glorot_normal  <class 'keras.optimizers.Adam'>
# 111        30        0       glorot_normal  <class 'keras.optimizers.Adam'>
# 397        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 294        30        0          he_uniform  <class 'keras.optimizers.Adam'>
# 255        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 256        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
# 254        30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 300        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 902        30        0        lecun_normal  <class 'keras.optimizers.Adam'>
# 703        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 1061       30        0       lecun_uniform  <class 'keras.optimizers.Adam'>
# 338        30        0           he_normal  <class 'keras.optimizers.Adam'>
# 769        30        0      glorot_uniform  <class 'keras.optimizers.Adam'>
#
#           lr  activation nodes    links  val_DetectRate_improvement
# 267   0.0010        ReLU    85   3570.0                   -0.000398
# 414   0.0010       PReLU    70   2415.0                   -0.001133
# 205   0.0010        SELU    85   3570.0                    0.000374
# 406   0.0010       PReLU    90   4005.0                   -0.000894
# 316   0.0010   LeakyReLU    95   4465.0                   -0.000141
# 227   0.0010        SELU    85   3570.0                   -0.002274
# 209   0.0010        SELU    85   3570.0                   -0.000240
# 351   0.0010       PReLU    75   2775.0                   -0.000680
# 425   0.0010       PReLU    65   2080.0                   -0.001724
# 264   0.0010        ReLU    90   4005.0                   -0.000146
# 213   0.0010        SELU    75   2775.0                   -0.000549
# 448   0.0100       PReLU    80   3160.0                   -0.004397
# 437   0.0010       PReLU    80   3160.0                   -0.002131
# 449   0.0100       PReLU    95   4465.0                   -0.005192
# 313   0.0010   LeakyReLU    85   3570.0                    0.000061
# 263   0.0001        ReLU    85   3570.0                    0.000120
# 359   0.0010       PReLU    75   2775.0                   -0.000873
# 221   0.0100        SELU    85   3570.0                   -0.001421
# 446   0.0100       PReLU    75   2775.0                   -0.003968
# 384   0.0100       PReLU    80   3160.0                   -0.004938
# 444   0.0010       PReLU    75   2775.0                   -0.002948
# 284   0.0100        ReLU   105   5460.0                   -0.002937
# 270   0.0001        ReLU    85   3570.0                   -0.000504
# 331   0.0001   LeakyReLU    95   4465.0                   -0.002526
# 329   0.0001   LeakyReLU    85   3570.0                   -0.002286
# 328   0.0001   LeakyReLU    75   2775.0                   -0.001798
# 440   0.0001       PReLU   105   5460.0                   -0.002682
# 438   0.0001       PReLU    90   4005.0                   -0.002551
# 380   0.0001       PReLU   100   4950.0                   -0.002689
# 336   0.0100   LeakyReLU    65   2080.0                   -0.004748
# ...      ...         ...   ...      ...                         ...
# 243   0.1000        SELU    85   3570.0                   -0.412426
# 701   0.1000   LeakyReLU   115   6555.0                   -0.394513
# 342   0.1000   LeakyReLU   100   4950.0                   -0.421615
# 778   0.1000        ReLU   135   9045.0                   -0.423609
# 340   0.1000   LeakyReLU    90   4005.0                   -0.410184
# 777   0.1000        ReLU   135   9045.0                   -0.404426
# 711   0.1000   LeakyReLU   120   7140.0                   -0.473891
# 1000  0.0100         ELU   165  13530.0                   -0.172199
# 247   0.1000        SELU    80   3160.0                   -0.444717
# 160   0.1000       PReLU    30    435.0                   -0.328449
# 245   0.1000        SELU    85   3570.0                   -0.438863
# 110   0.1000        SELU    50   1225.0                   -0.233585
# 999   0.0100         ELU   160  12720.0                   -0.171099
# 779   0.1000        ReLU   100   4950.0                   -0.435252
# 249   0.1000        SELU    85   3570.0                   -0.468575
# 716   0.1000   LeakyReLU   105   5460.0                   -0.484190
# 774   0.1000        ReLU   135   9045.0                   -0.349500
# 707   0.1000   LeakyReLU   115   6555.0                   -0.467705
# 111   0.1000        SELU    50   1225.0                   -0.315509
# 397   0.1000       PReLU    65   2080.0                   -0.502000
# 294   0.1000        ReLU    85   3570.0                   -0.169589
# 255   0.1000        SELU    85   3570.0                   -0.535928
# 256   0.1000        SELU    75   2775.0                   -0.544334
# 254   0.1000        SELU   100   4950.0                   -0.535877
# 300   0.1000        ReLU   100   4950.0                   -0.452335
# 902   0.0100   LeakyReLU   165  13530.0                   -0.180254
# 703   0.1000   LeakyReLU   120   7140.0                   -0.452262
# 1061  0.0100        ReLU   170  14365.0                   -0.138034
# 338   0.1000   LeakyReLU    90   4005.0                   -0.181415
# 769   0.1000        ReLU   125   7750.0                   -0.233412
#
# [1062 rows x 21 columns]

# %%
import seaborn as sns
metric = 'first_neuron'
ax = sns.boxplot(x=metric, y="val_DetectRate_improvement", data=df.reset_index(),color='salmon')
ax.set_title('Log-DetectionRate Improvement as function of Neurons in First Layer')
# Increasing neurons have a strong, positive impact
# Out:
# Text(0.5,1,'Log-DetectionRate Improvement as function of Neurons in First Layer')

# %%
df['val_DetectRate']=df['acc']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
metric = 'first_neuron'
ax = sns.boxplot(x=metric, y="val_DetectRate", data=df.reset_index(),color='salmon')
ax.set_title('Log-DetectionRate Improvement as a function of Neurons in the First Layer')
# Increasing neurons have a strong, positive impact
plt.ylim(bottom=0.75)
plt.savefig('./image/LOgDetectRate-FirstLayer.eps',dpi=1000)

# %%
metric = 'second_neuron'
ax = sns.boxplot(x=metric, y="val_DetectRate_improvement", data=df.reset_index(),color='salmon')
ax.set_title('Log-DetectionRate Improvement as function of Neurons in Second Layer')
# Increasing neurons have a strong, positive impact
# Out:
# Text(0.5,1,'Log-DetectionRate Improvement as function of Neurons in Second Layer')

# %%
plt.figure(figsize=(10, 5))
metric = 'second_neuron'
ax = sns.boxplot(x=metric, y="val_DetectRate", data=df.reset_index(),color='salmon')
ax.set_title('Log-DetectionRate Improvement as a function of Neurons in the Second Layer')
# Increasing neurons have a strong, positive impact
plt.ylim(bottom=0.7)
plt.savefig('./image/LOgDetectRate-SecondLayer.eps',dpi=1000)

# %%
metric = 'third_neuron'
ax = sns.boxplot(x=metric, y="val_DetectRate_improvement", data=df.reset_index(),color='salmon')
ax.set_title('Log-DetectionRate Improvement as function of Neurons in Third Layer')
# Increasing neurons have a strong, positive impact
# Out:
# Text(0.5,1,'Log-DetectionRate Improvement as function of Neurons in Third Layer')

# %%
plt.figure(figsize=(10, 5))
metric = 'third_neuron'
ax = sns.boxplot(x=metric, y="val_DetectRate", data=df.reset_index(),color='salmon')
ax.set_title('Log-DetectionRate Improvement as a function of Neurons in the Third Layer')
# Increasing neurons have a strong, positive impact
plt.ylim(bottom=0.75)
plt.savefig('./image/LOgDetectRate-ThirdLayer.eps',dpi=1000)

# %%
metric = 'fourth_neuron'
ax = sns.boxplot(x=metric, y="val_DetectRate_improvement", data=df.reset_index(),color='salmon')
ax.set_title('Log-DetectionRate Improvement as function of Neurons in Forth Layer')
# Increasing neurons have a strong, positive impact
# Out:
# Text(0.5,1,'Log-DetectionRate Improvement as function of Neurons in Forth Layer')

# %%
plt.figure(figsize=(10, 5))
metric = 'fourth_neuron'
ax = sns.boxplot(x=metric, y="val_DetectRate", data=df.reset_index(),color='salmon')
ax.set_title('Log-DetectionRate Improvement as a function of Neurons in the Fourth Layer')
# Increasing neurons have a strong, positive impact
plt.ylim(bottom=0.75)
plt.savefig('./image/LOgDetectRate-ThirdLayer.eps',dpi=1000)

# %%
metric = 'hidden_layer'
ax = sns.boxplot(x=metric, y="val_DetectRate_improvement", data=df.reset_index(),color='salmon')
ax.set_title(f'Log-val DetectRate Improvement as function of {metric}')
# Surprisingly, no hidden layers is consistently best
# Out:
# Text(0.5,1,'Log-val DetectRate Improvement as function of hidden_layer')

# %%
metric = 'hidden_layer'
plt.figure(figsize=(10, 5))
ax = sns.boxplot(x=metric, y="val_DetectRate", data=df.reset_index(),color='salmon')
ax.set_title(f'Log-val DetectRate Improvement as a Function of {metric}')
# Surprisingly, no hidden layers is consistently best
plt.ylim(bottom=0.75)
plt.savefig('./image/LOgDetectRate-hiddenLayer.eps',dpi=1000)

# %%
metric = 'lr'
plt.figure(figsize=(10, 5))
ax = sns.boxplot(x=metric, y="val_DetectRate_improvement", data=df.reset_index(),color='salmon')
ax.set_title(f'Validation DetectRate as a function of {metric}')
# Generally, larger batch sizes don't hurt (and train faster)
# Out:
# Text(0.5,1,'Validation DetectRate as a function of lr')

# %%
metric = 'lr'
plt.figure(figsize=(10, 5))
ax = sns.boxplot(x=metric, y="val_DetectRate", data=df.reset_index(),color='salmon')
ax.set_title(f'Validation DetectRate as a function of {metric}')
# Generally, larger batch sizes don't hurt (and train faster)
plt.savefig('./image/DetectRateImprovement-lr.eps',dpi=1000)

# %%
metric = 'batch_size'
ax = sns.boxplot(x=metric, y="val_DetectRate_improvement", data=df.reset_index(),color='salmon')
ax.set_title(f'Validation DetectRate as function of {metric}')
# Generally, larger batch sizes don't hurt (and train faster)
# Out:
# Text(0.5,1,'Validation DetectRate as function of batch_size')

# %%
metric = 'batch_size'
plt.figure(figsize=(10, 5))
ax = sns.boxplot(x=metric, y="val_DetectRate", data=df.reset_index(),color='salmon')
ax.set_title(f'Validation Loss as a Function of {metric}')
# Generally, larger batch sizes don't hurt (and train faster)
plt.ylim(bottom=0.75)
plt.savefig('./image/DetectRateImprovement-batchsize.eps',dpi=1000)

# %%
from sklearn.preprocessing import MinMaxScaler
X = df[['first_neuron','second_neuron','third_neuron','fourth_neuron','hidden_layer','lr','batch_size']]
scaler = MinMaxScaler()
y = scaler.fit_transform(df[['val_DetectRate_improvement']])

from sklearn.ensemble import RandomForestRegressor

reg = RandomForestRegressor(max_depth=3,n_estimators=100)

plt.figure(figsize=(10, 5))
reg.fit(X,y)
pd.Series(reg.feature_importances_,index=X.columns).\
sort_values(ascending=True).plot.barh(color='grey',title='Feature Importance of Hyperparameters')
plt.savefig('./image/Importance ofHyperparaeters.eps',dpi=1000)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
print("Features sorted by their score:")
#print (sorted([(round(np.mean(reg.feature_importances), 4), feat) for
#              X.columns, reg.feature_importances in reg.feature_importances.items()], reverse=True))
print(pd.Series(reg.feature_importances_,index=X.columns).sort_values(ascending=False))
# Out:
# Features sorted by their score:
# lr               0.735720
# second_neuron    0.126663
# hidden_layer     0.082933
# batch_size       0.041900
# third_neuron     0.008256
# fourth_neuron    0.004356
# first_neuron     0.000171
# dtype: float64

# %%
ax = sns.regplot(x='links', y="round_epochs",x_bins=5,logx=True ,data=df[['links','round_epochs']],color='grey')
ax.set_xscale('log')

ax.set_title(f'Epochs Until Convergence vs. Link Count')
# Out:
# Text(0.5,1,'Epochs Until Convergence vs. Link Count')

# %%
df_grid = df.reset_index().groupby(["first_neuron", "hidden_layer"]).val_DetectRate_improvement.mean().unstack()
ax = sns.heatmap(data=df_grid,cmap = (sns.diverging_palette(10, 220, sep=80, n=7)),annot=True)
ax.set_title('Log-DetectRate Improvement for Varying Shapes')
# Unsurprisingly, bigger on both layer types is better.
# Out:
# Text(0.5,1,'Log-DetectRate Improvement for Varying Shapes')

# %%
df_grid = df.reset_index().groupby(["hidden_layer", "first_neuron"]).val_DetectRate_improvement.mean().unstack()
ax = sns.heatmap(data=df_grid,cmap = (sns.diverging_palette(10, 220, sep=80, n=7)),annot=True)
ax.set_title('Log-DetectRate Improvement for Varying Shapes')
# Out:
# Text(0.5,1,'Log-DetectRate Improvement for Varying Shapes')

# %%
df_grid = df.reset_index().groupby(["hidden_layer", "second_neuron"]).val_DetectRate_improvement.mean().unstack()
ax = sns.heatmap(data=df_grid,cmap = (sns.diverging_palette(10, 220, sep=80, n=7)),annot=True)
ax.set_title('Log-DetectRate Improvement for Varying Shapes')
# Out:
# Text(0.5,1,'Log-DetectRate Improvement for Varying Shapes')

# %%
df_grid = df.reset_index().groupby(["hidden_layer", "third_neuron"]).val_DetectRate_improvement.mean().unstack()
ax = sns.heatmap(data=df_grid,cmap = (sns.diverging_palette(10, 220, sep=80, n=7)),annot=True)
ax.set_title('Log-DetectRate Improvement for Varying Shapes')
# Out:
# Text(0.5,1,'Log-DetectRate Improvement for Varying Shapes')

# %%
df_grid = df.reset_index().groupby(["hidden_layer", "fourth_neuron"]).val_DetectRate_improvement.mean().unstack()
ax = sns.heatmap(data=df_grid,cmap = (sns.diverging_palette(10, 220, sep=80, n=7)),annot=True)
ax.set_title('Log-DetectRate Improvement for Varying Shapes')
# Out:
# Text(0.5,1,'Log-DetectRate Improvement for Varying Shapes')

# %%
df_grid = df.reset_index().groupby(["lr", "hidden_layer"]).val_DetectRate_improvement.mean().unstack()
ax = sns.heatmap(data=df_grid,cmap = (sns.diverging_palette(10, 220, sep=80, n=7)),annot=True)
ax.set_title('Log-DetectRate Improvement vs lr/Size')
# Surprisingly, dropout didn't help even at larger geometries
# Out:
# Text(0.5,1,'Log-DetectRate Improvement vs lr/Size')

# %%
df_grid = df.reset_index().groupby(["lr", "first_neuron"]).val_DetectRate_improvement.mean().unstack()
ax = sns.heatmap(data=df_grid,cmap = (sns.diverging_palette(10, 220, sep=80, n=7)),annot=True)
ax.set_title('Log-DetectRate Improvement vs lr/Size')
# Surprisingly, dropout didn't help even at larger geometries
# Out:
# Text(0.5,1,'Log-DetectRate Improvement vs lr/Size')

# %%
df_grid = df.reset_index().groupby(["lr", "second_neuron"]).val_DetectRate_improvement.mean().unstack()
ax = sns.heatmap(data=df_grid,cmap = (sns.diverging_palette(10, 220, sep=80, n=7)),annot=True)
ax.set_title('Log-DetectRate Improvement vs lr/Size')
# Surprisingly, dropout didn't help even at larger geometries
# Out:
# Text(0.5,1,'Log-DetectRate Improvement vs lr/Size')

# %%
df_grid = df.reset_index().groupby(["lr", "third_neuron"]).val_DetectRate_improvement.mean().unstack()
ax = sns.heatmap(data=df_grid,cmap = (sns.diverging_palette(10, 220, sep=80, n=7)),annot=True)
ax.set_title('Log-DetectRate Improvement vs lr/Size')
# Surprisingly, dropout didn't help even at larger geometries
# Out:
# Text(0.5,1,'Log-DetectRate Improvement vs lr/Size')

# %%
df_grid = df.reset_index().groupby(["lr", "fourth_neuron"]).val_DetectRate_improvement.mean().unstack()
ax = sns.heatmap(data=df_grid,cmap = (sns.diverging_palette(10, 220, sep=80, n=7)),annot=True)
ax.set_title('Log-DetectRate Improvement vs lr/Size')
# Surprisingly, dropout didn't help even at larger geometries
# Out:
# Text(0.5,1,'Log-DetectRate Improvement vs lr/Size')

# %%
df_grid = df.reset_index().groupby(["lr", "batch_size"]).val_DetectRate_improvement.mean().unstack()
ax = sns.heatmap(data=df_grid,cmap = (sns.diverging_palette(10, 220, sep=80, n=7)),annot=True)
ax.set_title('Log-DetectRate Improvement vs lr/Size')
# Surprisingly, dropout didn't help even at larger geometries
# Out:
# Text(0.5,1,'Log-DetectRate Improvement vs lr/Size')

# %%
sns.set(rc={"axes.facecolor":"#ccddff",
            "axes.grid":False,
            'axes.labelsize':15,
            'figure.figsize':(12.0, 5.0),
            'xtick.labelsize':12,
            'ytick.labelsize':15})

metric = 'kernel_initializer'
ax = sns.boxplot(x=metric, y="val_DetectRate",data=df.reset_index(), palette="Set2")
ax.set_title('Log-DetectRate Improvement as an effect of Kernel Initialization')
# Increasing neurons have a strong, positive impact
plt.ylim(bottom=0.75)
plt.savefig('./image/Log DetectRate vs KernelInitial.eps',dpi=1000)

# %%
metric = 'activation'
ax = sns.boxplot(x=metric, y="val_DetectRate",data=df.reset_index(), palette="Set2")
ax.set_title('Log-DetectRate Improvement as an Effect of Function Activation')
# Increasing neurons have a strong, positive impact
plt.ylim(bottom=0.75)
plt.savefig('./image/Log DetectRate vs Functionactv.eps',dpi=1000)

# %%
metric = 'activation'
ax = sns.boxplot(x=metric, y="val_DetectRate_improvement",data=df.reset_index(), palette="Set2")
ax.set_title('Log-DetectRate Improvement as function Avctivation')
# Increasing neurons have a strong, positive impact
# Out:
# Text(0.5,1,'Log-DetectRate Improvement as function Avctivation')
